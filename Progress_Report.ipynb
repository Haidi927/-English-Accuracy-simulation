# %%
id, 真实知识点          , LLM识别知识点       , 标签是否正确, 预测得分率, 真实得分率
21, 定语从句与名词性从句, 定语从句与名词性从句,            1,      0.432,       0.64
22, 冠词与代词          , 冠词与代词          ,            1,      0.829,       0.86
23, 冠词与代词          , 冠词与代词          ,            1,      0.829,       0.79
24, 定语从句与名词性从句, 定语从句与名词性从句,            1,      0.432,       0.22
25, 副词与比较结构      , 副词与比较结构      ,            1,      0.646,       0.65
26, 非谓语动词          , 非谓语动词          ,            1,      0.686,       0.57
27, 连词与状语从句      , 连词与状语从句      ,            1,      0.571,       0.57
28, 非谓语动词          , 非谓语动词          ,            1,      0.686,       0.77
29, 祈使句与动词原形    , 祈使句与动词原形    ,            1,      0.5  ,       0.5
30, 非谓语动词          , 非谓语动词          ,            1,      0.686,       0.71

# %%
你是一名具有多年命题经验的英语语法专家兼教师培训讲师。现在给你一份“语法填空”试题的 JSON 数据（包含 content、topic_score、每个空的 id 与答案）。  
请你根据上下文、空格处词性、语法结构和答案，准确判断每个空考查的【语法模块】与【知识点】，并将结果按照以下格式输出。

────────────────────────────
【六大核心语法模块（只能六选一）】

模块一：定语从句与名词性从句  
模块二：非谓语动词  
模块三：冠词与代词  
模块四：副词与比较结构  
模块五：连词与状语从句  
模块六：祈使句与动词原形

────────────────────────────
【判断逻辑与核心规则】

模块一：定语从句与名词性从句  
【触发信号】关系词 / 引导词：that, which, who, whose, what, whatever, when, where, why, whether, if, as 等；  
【典型结构】  
- 先行词 + 关系词 + 从句 → 定语从句（如 which means / that leads to）  
- 宾语从句 → what / whatever / whether + 主语 + 谓语  
【优先级】：出现关系词即优先归为此模块。  

模块二：非谓语动词  
【触发信号】动词原形带 to / -ing / -ed 形式；无主语独立出现。  
【判断规则】  
- to do → 主语或目的  
- doing → 主语、宾语或主动定语/状语  
- done → 被动定语或过去分词结构  
- having done → 动作先于主句发生。  

模块三：冠词与代词  
【触发信号】答案为 a / an / the / some / both / either / each / another / few 等限定词或代词。  
【判断规则】  
- 冠词选择基于发音、可数性或固定搭配。  
- 代词选择基于数量关系、语义逻辑。  

 模块四：副词与比较结构  
【触发信号】答案中出现副词（如 more + adv / adj, most + adv / adj, truly, really, genuinely）；  
【判断规则】  
- 修饰形容词 → 用副词形式；  
- 与 and / but 连用 → 并列比较结构。  

模块五：连词与状语从句  
【触发信号】because, as, since, while, although, unless, once, before, after 等。  
【判断规则】  
- 引导原因、条件、让步、时间、目的等从句；  
- 句中有两个谓语动词时常为状语从句。  

模块六：祈使句与动词原形  
【触发信号】句首或副词 + 动词原形（如 Simply choose, Please remember, Don’t forget）。  
【判断规则】  
- 无主语，语气为建议/指令；  
- 主句为动词原形，常用于说明文或倡议句。  

────────────────────────────
【示例输出】（仅供参考）

✅ 模块一：定语从句与名词性从句  
21	非限制性定语从句引导词 → which	which 可指代整个主句；that 不能用于非限制性从句  
24	宾语从句连接词 → what / whatever	what = the thing(s) that；whatever 更强调“无论什么”  

✅ 模块二：非谓语动词  
26	不定式作主语 → to copy	it 作形式主语时，真正主语为 to do 结构  
...

────────────────────────────
请严格遵循以上分类与表格格式，用简洁、教学化的语言撰写说明。



────────────────────────────
【输出格式要求】
仅输出以下 JSON 对象，不要输出任何解释、前后缀、代码块标记：
{
  "topic_type": "语法填空",
  "items": [
    {"id": 21, "knowledge_point": "从句运用"}
  ]
}

────────────────────────────
【输入数据】
{{exam_json}}
